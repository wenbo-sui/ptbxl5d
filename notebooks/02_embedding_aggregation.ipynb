# %% [markdown]
# <div class='alert-block' style='background-color: #007bff; color: #ffffff;'>
#     <br>
#     <h1 align="center"><b>Part 2：</b> Multi-Lead ECG Autoencoder with Embedding Aggregation</h1>
#     <h5 align="center">Wenbo Sui</h5>
#     <br>
# </div>

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import wfdb
import os
import numpy as np
import pandas as pd
import numpy as np
import wfdb
import ast

import sys
root_path = os.path.abspath(os.path.join(os.getcwd(), ".."))
if root_path not in sys.path:
    sys.path.append(root_path)

from src.autoencoder import UNet_SE

# %%
device = torch.device("mps")
model = UNet_SE().to(device)
